# %% [markdown]
# ## `01 ___ PstFrom`    ___________   ` part2_02_pstfrom `

# %%
import os 
import pyemu
import pandas as pd

# %%
model_ws = os.path.join('..', '..', 'models', 'monthly_model_files_1lyr_newstress') 

# added ... [MF6.exe & pestpp-ies.exe]  ... at monthly folder ____________  neads also the archive mfsim.nam)

# %%
pyemu.os_utils.run('mf6',cwd=model_ws)
# Out:
# mf6.exe

# %%
pf = pyemu.utils.PstFrom(model_ws,'a2_Pstfrom_Fienen_new_folder',remove_existing=True)         # New folder
# Out:
# 2025-01-02 14:52:39.606010 starting: opening PstFrom.log for logging
# 2025-01-02 14:52:39.606234 starting PstFrom process
# 2025-01-02 14:52:39.606382 starting: setting up dirs
# 2025-01-02 14:52:39.606596 starting: removing existing new_d 'a2_Pstfrom_Fienen_new_folder'
# 2025-01-02 14:52:39.634229 finished: removing existing new_d 'a2_Pstfrom_Fienen_new_folder' took: 0:00:00.027633
# 2025-01-02 14:52:39.634312 starting: copying original_d '..\..\models\monthly_model_files_1lyr_newstress' to new_d 'a2_Pstfrom_Fienen_new_folder'
# 2025-01-02 14:52:39.704212 finished: copying original_d '..\..\models\monthly_model_files_1lyr_newstress' to new_d 'a2_Pstfrom_Fienen_new_folder' took: 0:00:00.069900
# 2025-01-02 14:52:39.705021 finished: setting up dirs took: 0:00:00.098639

# %% [markdown]
# ## `02 ___ Adding Parameters`

# %%
pf.add_parameters('freyberg6.npf_k_layer1.txt',par_type='grid')
# FOLDERS     # .. \Beta_Beta_template\mult\p_inst0_grid.csv     &    # .. \Beta_Beta_template\org\freyberg6.npf_k_layer1.txt
# Out:
# 2025-01-02 14:52:40.773924 transform was not passed, setting default tranform to 'log'
# 2025-01-02 14:52:40.774347 starting: adding grid type m style parameters for file(s) ['freyberg6.npf_k_layer1.txt']
# 2025-01-02 14:52:40.774561 starting: loading array a2_Pstfrom_Fienen_new_folder\freyberg6.npf_k_layer1.txt
# 2025-01-02 14:52:40.784528 finished: loading array a2_Pstfrom_Fienen_new_folder\freyberg6.npf_k_layer1.txt took: 0:00:00.009967
# 2025-01-02 14:52:40.784599 loaded array '..\..\models\monthly_model_files_1lyr_newstress\freyberg6.npf_k_layer1.txt' of shape (40, 20)
# 2025-01-02 14:52:40.787068 starting: writing array-style template file 'a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl'
# 2025-01-02 14:52:40.787149 starting: writing template file a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl for ['p_inst:0']
# 2025-01-02 14:52:40.799616 finished: writing template file a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl for ['p_inst:0'] took: 0:00:00.012467
# 2025-01-02 14:52:40.799672 starting: writing array-based template file 'a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl'
# 2025-01-02 14:52:40.806201 finished: adding grid type m style parameters for file(s) ['freyberg6.npf_k_layer1.txt'] took: 0:00:00.031854
#                                                                                                                 parnme  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00          pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00          pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00          pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00          pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00          pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00
# ...                                                                                                                ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00
#
#                                                             parval1   i   j  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00          1.0   0   0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00          1.0   0   1
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00          1.0   0   2
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00          1.0   0   3
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00          1.0   0   4
# ...                                                             ...  ..  ..
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00      1.0  39  15
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00      1.0  39  16
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00      1.0  39  17
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00      1.0  39  18
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00      1.0  39  19
#
#                                                              x   y     pargp  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00       0   0  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00       0   1  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00       0   2  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00       0   3  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00       0   4  p_inst:0
# ...                                                         ..  ..       ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  39  15  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  39  16  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  39  17  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  39  18  p_inst:0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  39  19  p_inst:0
#
#                                                                                                  tpl_filename  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00      a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00      a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00      a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00      a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00      a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl
# ...                                                                                                       ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  a2_Pstfrom_Fienen_new_folder\p_inst0_grid.csv.tpl
#
#                                                                                                 input_filename  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00      a2_Pstfrom_Fienen_new_folder\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00      a2_Pstfrom_Fienen_new_folder\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00      a2_Pstfrom_Fienen_new_folder\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00      a2_Pstfrom_Fienen_new_folder\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00      a2_Pstfrom_Fienen_new_folder\mult\p_inst0_grid.csv
# ...                                                                                                        ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  a2_Pstfrom_Fienen_new_folder\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  a2_Pstfrom_Fienen_new_folder\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  a2_Pstfrom_Fienen_new_folder\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  a2_Pstfrom_Fienen_new_folder\mult\p_inst0_grid.csv
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  a2_Pstfrom_Fienen_new_folder\mult\p_inst0_grid.csv
#
#                                                            partype partrans  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00        grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00        grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00        grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00        grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00        grid      log
# ...                                                            ...      ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00    grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00    grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00    grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00    grid      log
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00    grid      log
#
#                                                                  parubnd  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00      1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00      1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00      1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00      1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00      1.000000e+10
# ...                                                                  ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  1.000000e+10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  1.000000e+10
#
#                                                                  parlbnd  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00      1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00      1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00      1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00      1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00      1.000000e-10
# ...                                                                  ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00  1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00  1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00  1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00  1.000000e-10
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00  1.000000e-10
#
#                                                             offset parchglim  \
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00         0.0    factor
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00         0.0    factor
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00         0.0    factor
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00         0.0    factor
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00         0.0    factor
# ...                                                            ...       ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00     0.0    factor
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00     0.0    factor
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00     0.0    factor
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00     0.0    factor
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00     0.0    factor
#
#                                                             dercom  scale
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:0.00_y:0.00           1    1.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:0.00_y:1.00           1    1.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:0.00_y:2.00           1    1.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:0.00_y:3.00           1    1.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:0.00_y:4.00           1    1.0
# ...                                                            ...    ...
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:15_x:39.00_y:15.00       1    1.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:16_x:39.00_y:16.00       1    1.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:17_x:39.00_y:17.00       1    1.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:18_x:39.00_y:18.00       1    1.0
# pname:p_inst:0_ptype:gr_pstyle:m_i:39_j:19_x:39.00_y:19.00       1    1.0
#
# [800 rows x 17 columns]

# %% [markdown]
# # `03 ___ Adding Observations`

# %%
h = pd.read_csv(os.path.join(model_ws , 'heads.csv'))                                # h     Supressed (just reading)
pf.add_observations('heads.csv',index_cols='time',use_cols=h.columns.tolist()[1:])
# Out:
# 2025-01-02 14:52:41.960348 starting: adding observations from output file heads.csv
# 2025-01-02 14:52:41.960642 starting: adding observations from tabular output file '['heads.csv']'
# 2025-01-02 14:52:41.960790 starting: reading list-style file: a2_Pstfrom_Fienen_new_folder\heads.csv
# 2025-01-02 14:52:41.965372 finished: reading list-style file: a2_Pstfrom_Fienen_new_folder\heads.csv took: 0:00:00.004582
# 2025-01-02 14:52:41.967758 starting: building insfile for tabular output file heads.csv
# 2025-01-02 14:52:41.974269 finished: building insfile for tabular output file heads.csv took: 0:00:00.006511
# 2025-01-02 14:52:41.974456 starting: adding observation from instruction file 'a2_Pstfrom_Fienen_new_folder\heads.csv.ins'
# 2025-01-02 14:52:41.992022 finished: adding observation from instruction file 'a2_Pstfrom_Fienen_new_folder\heads.csv.ins' took: 0:00:00.017566
# 2025-01-02 14:52:41.992927 finished: adding observations from tabular output file '['heads.csv']' took: 0:00:00.032285
# 2025-01-02 14:52:41.993020 finished: adding observations from output file heads.csv took: 0:00:00.032672
#                                                                                                               obsnme  \
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3652.5  oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3652.5
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3683.5  oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3683.5
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3712.5  oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3712.5
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3743.5  oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3743.5
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3773.5  oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3773.5
# ...                                                                                                              ...
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4261.5      oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4261.5
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4291.5      oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4291.5
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4322.5      oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4322.5
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4352.5      oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4352.5
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4383.5      oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4383.5
#
#                                                               obsval  weight  \
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3652.5  34.797358     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3683.5  34.768494     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3712.5  34.821230     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3743.5  34.920983     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3773.5  35.008383     1.0
# ...                                                              ...     ...
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4261.5    36.302093     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4291.5    36.049412     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4322.5    35.791469     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4352.5    35.602397     1.0
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4383.5    35.559841     1.0
#
#                                                                                                   obgnme
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3652.5  oname:heads.csv_otype:lst_usecol:trgw-0-13-10
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3683.5  oname:heads.csv_otype:lst_usecol:trgw-0-13-10
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3712.5  oname:heads.csv_otype:lst_usecol:trgw-0-13-10
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3743.5  oname:heads.csv_otype:lst_usecol:trgw-0-13-10
# oname:heads.csv_otype:lst_usecol:trgw-0-13-10_time:3773.5  oname:heads.csv_otype:lst_usecol:trgw-0-13-10
# ...                                                                                                  ...
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4261.5      oname:heads.csv_otype:lst_usecol:trgw-0-9-1
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4291.5      oname:heads.csv_otype:lst_usecol:trgw-0-9-1
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4322.5      oname:heads.csv_otype:lst_usecol:trgw-0-9-1
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4352.5      oname:heads.csv_otype:lst_usecol:trgw-0-9-1
# oname:heads.csv_otype:lst_usecol:trgw-0-9-1_time:4383.5      oname:heads.csv_otype:lst_usecol:trgw-0-9-1
#
# [325 rows x 4 columns]

# %% [markdown]
# # `04 ___ PEST`

# %%
pf.mod_sys_cmds.append('mf6')

# %%
pst = pf.build_pst(filename=os.path.join(pf.new_d,'freyberg.pst'),version=2)
# Out:
# noptmax:0, npar_adj:800, nnz_obs:325
# 2025-01-02 14:52:44.356359 forward_run line:pyemu.os_utils.run(r'mf6')

# %%
pyemu.os_utils.run('pestpp-ies freyberg.pst',cwd='a2_Pstfrom_Fienen_new_folder')  # New Beta path
# Out:
# pestpp-ies.exe freyberg.pst

# %% [markdown]
# # `05 ___obs, weights, and prior MC`

# %%
pst
pst = pyemu.Pst('a2_Pstfrom_Fienen_new_folder/freyberg.pst')                     # New Beta path

# %%
trueobs = pd.read_csv('./data/obstrue.csv', index_col=0)
# trueobs

# %%
obs = pst.observation_data                   # index
for cob in obs.index:
    tmp = obs.loc[cob]                       # Loop OBS_location  & Time
    print(trueobs.loc[(trueobs.time==float(tmp.time))&(trueobs.location==tmp.usecol), 'observation'].values[0])
    obs.loc[cob,'obsval'] = trueobs.loc[(trueobs.time==float(tmp.time))&(trueobs.location==tmp.usecol), 'observation'].values[0]
# Out:
# 35.88016773
# 35.7867735
# 35.78463464
# 35.81843897
# 35.88725726
# 35.93567392
# 35.94577231
# 35.92082717
# 35.86105688
# 35.67364845
# 35.47040371
# 35.30551308
# 35.2238309
# 35.25642906
# 35.34517989
# 35.47839102
# 35.5918731
# 35.71176064
# 35.78496164
# 35.79768162
# 35.69234994
# 35.48965616
# 35.26465122
# 35.09536629
# 34.96031282
# 35.23109255
# 35.15742713
# 35.14732154
# 35.18849072
# 35.26233823
# 35.31237888
# 35.30556272
# 35.24908381
# 35.17835713
# 35.03732028
# 34.90155737
# 34.78683512
# 34.71675972
# 34.72397708
# 34.80477803
# 34.92759017
# 35.03894715
# 35.14078638
# 35.18564878
# 35.17440704
# 35.06846277
# 34.91605067
# 34.75965813
# 34.63786718
# 34.52733821
# 35.15626217
# 35.13854355
# 35.14377989
# 35.17989508
# 35.24008305
# 35.29105008
# 35.31042826
# 35.2841944
# 35.2329732
# 35.15348678
# 35.07410528
# 35.00384546
# 34.94364716
# 34.9239258
# 34.95869786
# 35.02959903
# 35.10462349
# 35.17733373
# 35.21303988
# 35.21028853
# 35.15430159
# 35.07419602
# 34.9899994
# 34.91699312
# 34.84687015
# 37.65065077
# 37.64106837
# 37.6647146
# 37.73063359
# 37.84311648
# 37.9488985
# 38.01799093
# 38.01249807
# 37.9425574
# 37.80575477
# 37.63568255
# 37.46652075
# 37.31114761
# 37.2334472
# 37.25689809
# 37.35934266
# 37.48204019
# 37.60814545
# 37.68641607
# 37.70185865
# 37.63363871
# 37.50103771
# 37.33262041
# 37.16338571
# 36.99781973
# 36.32424578
# 36.19482298
# 36.14875131
# 36.15753826
# 36.22281955
# 36.27981212
# 36.27092476
# 36.23903324
# 36.17118196
# 35.98153696
# 35.756695
# 35.54972492
# 35.40828405
# 35.35268038
# 35.39657223
# 35.47316716
# 35.57132119
# 35.67812968
# 35.75420643
# 35.79115457
# 35.67289185
# 35.44858042
# 35.17577601
# 34.95121156
# 34.74197664
# 35.19711589
# 35.0919725
# 35.06908478
# 35.08382286
# 35.14075696
# 35.18333304
# 35.1699868
# 35.13877233
# 35.08450372
# 34.96169712
# 34.83871131
# 34.7196302
# 34.62930924
# 34.60518542
# 34.65021241
# 34.73116461
# 34.82496102
# 34.91589831
# 34.97254452
# 34.97423619
# 34.88406491
# 34.74567762
# 34.59955457
# 34.46635916
# 34.3346773
# 38.31680837
# 38.2565792
# 38.23563972
# 38.26405372
# 38.33618234
# 38.44347639
# 38.49011913
# 38.45695178
# 38.34776781
# 38.07763554
# 37.75293612
# 37.47679677
# 33.34723135
# 32.40801786
# 29.76899626
# 31.32925347
# 31.0534261
# 31.97695378
# 32.93289506
# 31.63750019
# 33.09244194
# 31.30882234
# 29.27811373
# 28.48525379
# 28.10658142
# 37.37371215
# 37.20404746
# 37.17793906
# 37.1761832
# 37.2536486
# 37.30907664
# 37.30123776
# 37.30200064
# 37.23100101
# 36.94555965
# 36.62836525
# 36.36315011
# 36.18029673
# 36.01031557
# 35.97628764
# 35.94376046
# 36.00088134
# 36.10018572
# 36.20745153
# 36.29895715
# 36.11062582
# 35.74551657
# 35.37239844
# 35.09570401
# 34.81246586
# 34.91457661
# 34.86926337
# 34.85013116
# 34.8684091
# 34.92309341
# 34.96632826
# 34.96150375
# 34.91399153
# 34.8490292
# 34.73417256
# 34.60633252
# 34.49576366
# 34.41569574
# 34.40814461
# 34.4665745
# 34.56010155
# 34.6478011
# 34.72372817
# 34.75929027
# 34.75593566
# 34.67944984
# 34.55452529
# 34.40702977
# 34.28552186
# 34.17270874
# 38.00429269
# 37.99381933
# 38.01940006
# 38.08862495
# 38.20362719
# 38.31149208
# 38.38334919
# 38.38085269
# 38.30941741
# 38.15454922
# 37.95866896
# 37.77110717
# 37.61231354
# 37.54446994
# 37.57878998
# 37.68706417
# 37.81184378
# 37.94054986
# 38.02184018
# 38.03919833
# 37.96526858
# 37.81323207
# 37.61846953
# 37.43085599
# 37.25501693
# 36.43789409
# 36.31670973
# 36.29095826
# 36.32421996
# 36.41321474
# 36.4797958
# 36.42594854
# 36.36607942
# 36.27238088
# 36.00062213
# 35.6814981
# 35.45079976
# 35.36775264
# 35.42978239
# 35.52090006
# 35.61958409
# 35.72030505
# 35.8201294
# 35.90175259
# 35.9485624
# 35.84050912
# 35.54424393
# 35.16495107
# 34.90824893
# 34.71220997
# 35.38970068
# 35.19251818
# 35.19097454
# 35.20851333
# 35.26939717
# 35.33773327
# 35.29026436
# 35.26843448
# 35.20149239
# 34.94747383
# 34.74606495
# 34.57524422
# 34.4733645
# 34.54322379
# 34.65105674
# 34.78387976
# 34.8817551
# 35.00236348
# 35.08490349
# 35.07080825
# 34.92734583
# 34.6625868
# 34.40999621
# 34.22588004
# 34.04015031
# 39.72085911
# 39.70613539
# 39.75151931
# 39.84619339
# 39.98200867
# 40.11553879
# 40.21344696
# 40.22620903
# 40.13562669
# 39.91999884
# 39.64368307
# 39.38455685
# 39.1775779
# 39.09199874
# 39.13061103
# 39.24129165
# 39.35667023
# 39.47526083
# 39.55031964
# 39.55039819
# 39.43283029
# 39.21451907
# 38.93656175
# 38.67605992
# 38.43780157

# %%
obs.weight=0.5

# %%
pst.plot(kind='phi_pie')
# Out:
# <Axes: >

# %%
newbalance = {grp:1/len(pst.obs_groups)*pst.phi for grp in pst.obs_groups}
newbalance
# Out:
# {'oname:heads.csv_otype:lst_usecol:trgw-0-13-10': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-15-16': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-2-15': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-2-9': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-21-10': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-22-15': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-24-4': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-26-6': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-29-15': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-3-8': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-33-7': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-34-10': np.float64(18.903509920398),
#  'oname:heads.csv_otype:lst_usecol:trgw-0-9-1': np.float64(18.903509920398)}

# %%
pst.adjust_weights(obsgrp_dict=newbalance)
pst.plot(kind='phi_pie')          # ifError <img src=" ./Weights.png" style="float: center; width: 75%;  margin-bottom: 0.5em;">
# Out:
# <Axes: >

# %% [markdown]
# # `06 ___ Weights Group` ______ `Heads x Flux x Concentration`

# %%
# pst.observation_data       # Weights varing in groups !

# %%
pst.control_data.noptmax=-1
pst.pestpp_options['ies_num_reals']=100

# %%
pst.parameter_data.parlbnd=0.5
pst.parameter_data.parubnd=1.5

# %%
pst.write('a2_Pstfrom_Fienen_new_folder/freyberg_prior.pst')                       # New Beta path
# Out:
# noptmax:-1, npar_adj:800, nnz_obs:325

# %%
# import shutil  shutil.copy2('pestpp-ies','Beta_template/pestpp-ies')

# %% [markdown]
# #  ` 07 ___  Running _____ w/ slaves`

# %%
pyemu.utils.start_workers('./a2_Pstfrom_Fienen_new_folder',master_dir='cm_prior', exe_rel_path='pestpp-ies',pst_rel_path='freyberg_prior.pst',worker_root='.', num_workers=10)

# %% [markdown]
# #  ` 08 ___ afterwords`

# %%
phi = pd.read_csv('cm_prior/freyberg_prior.phi.actual.csv').T[6:]         
phi
# Out:
#             0
# 0     241.463
# 1     240.939
# 2     247.583
# 3     247.359
# 4     246.463
# 5     244.460
# 6     241.304
# 7     245.675
# 8     244.516
# 9     243.337
# 10    242.938
# 11    239.086
# 12    246.993
# 13    240.167
# 14    241.705
# 15    240.330
# 16    242.154
# 17    245.045
# 18    241.443
# 19    240.137
# 20    241.713
# 21    241.272
# 22    244.504
# 23    245.732
# 24    241.672
# 25    240.133
# 26    246.522
# 27    242.483
# 28    238.201
# 29    246.192
# 30    239.685
# 31    239.868
# 32    239.723
# 33    245.742
# 34    244.453
# 35    248.267
# 36    242.899
# 37    242.198
# 38    241.051
# 39    243.547
# 40    241.744
# 41    240.589
# 42    244.322
# 43    242.806
# 44    245.436
# 45    245.529
# 46    244.805
# 47    241.914
# 48    245.362
# 49    241.221
# 50    243.070
# 51    240.112
# 52    243.293
# 53    243.961
# 54    243.044
# 55    243.010
# 56    239.401
# 57    244.270
# 58    243.493
# 59    246.964
# 60    242.223
# 61    245.221
# 62    243.525
# 63    245.417
# 64    241.704
# 65    241.935
# 66    243.574
# 67    242.064
# 68    241.842
# 69    241.960
# 70    242.394
# 71    242.388
# 72    236.878
# 73    244.968
# 74    244.896
# 75    241.693
# 76    243.468
# 77    244.803
# 78    242.191
# 79    244.176
# 80    243.798
# 81    244.759
# 82    244.550
# 83    241.074
# 84    244.648
# 85    247.115
# 86    244.885
# 87    246.231
# 88    237.912
# 89    241.486
# 90    242.852
# 91    244.509
# 92    244.098
# 93    244.252
# 94    247.415
# 95    242.527
# 96    243.068
# 97    240.541
# 98    245.414
# base  245.746

# %%
phi.hist(bins=20)  # err
# Out:
# array([[<Axes: title={'center': '0'}>]], dtype=object)

# %%
# Beta Paste picture err

# %% [markdown]
# # ... still under BETA revision ...

# %%
df = pd.read_csv('cm_prior/freyberg_prior.phi.actual.csv').T[6:] 
print(df)
# Out:
#             0
# 0     241.463
# 1     240.939
# 2     247.583
# 3     247.359
# 4     246.463
# ...       ...
# 95    242.527
# 96    243.068
# 97    240.541
# 98    245.414
# base  245.746
#
# [100 rows x 1 columns]

# %% [markdown]
# # PART 1.5 - rejection sampling

# %% [markdown]
# #reject by convergence fail counts                                              # Markdown / code / err
# pr_oe = pd.read_csv(os.path.join('cm_prior','freyberg_prior.0.obs.csv'))
# fails = pr_oe.loc[:,pr_oe.columns.str.contains('fail')]
# good_enough = fails.loc[fails['oname:convergence_failure_counts.csv_otype:lst_usecol:count_type:flow_fails']<1].index.values
# print("number of good enough realisations:", good_enough.shape[0])

# %%
#reject by mass balance error (> 5%)
mbe = pr_oe.loc[:,pr_oe.columns.str.contains('percent_discrepancy')].max(axis=1)
good_enough = mbe.loc[mbe.values<5].index.values
print("number of good enough realisations:", good_enough.shape[0])
# Out:
# number of good enough realisations: 0

# %% [markdown]
# #reject by phi                                                                  # Markdown / code / err
# acceptable_phi = og_phi * 2
# good_enough = df.loc[df[0]<acceptable_phi].index.values
# print("number of good enough realisations:", good_enough.shape[0])
# print(good_enough)

# %% [markdown]
# PART 2 - iES

# %%
import shutil

# %%
t_d = 'tmp'
if os.path.exists(t_d):
    shutil.rmtree(t_d)
shutil.copytree('cm_prior',t_d)
#hot start with rejection prior. need to rename files!
for filename,argname in zip(["freyberg_prior.0.par.csv","freyberg_prior.0.obs.csv","freyberg_prior.obs+noise.csv"],
                            ["ies_parameter_ensemble","ies_restart_observation_ensemble","ies_observation_ensemble"]):
    #load in and only keep "good enough" index
    df = pd.read_csv(os.path.join('cm_prior',filename),index_col=0)    
    df = df.loc[df.index.isin(good_enough),:]
    # a simple renaming scheme
    renamed_filename = "restart_"+filename
    # copy the original restart file from the prior master dir to the renamed filename in the template dir
    df.to_csv(os.path.join(t_d,renamed_filename))
    #modify/set the pestpp option
    pst.pestpp_options[argname] = renamed_filename

# %% [markdown]
# pst.control_data.noptmax = 2                                                                    # Markdown / code / err
# pst.pestpp_options['ies_drop_conflicts']=True
# pst.write(os.path.join(t_d,"freyberg_ies.pst"),version=2)
# prep_deps(t_d)

# %% [markdown]
# m_d = 'master_ies'                                                                              # Markdown / code / err
# pyemu.os_utils.start_workers(t_d, # the folder which contains the "template" PEST dataset
#                             'pestpp-ies', #the PEST software version we want to run
#                             'freyberg_ies.pst', # the control file to use with PEST
#                             num_workers=10, #how many agents to deploy
#                             worker_root='.', #where to deploy the agent directories; relative to where python is running
#                             master_dir=m_d, #the manager directory
#                             )

# %% [markdown]
# ## `On spurious correlation`
#
# Calculating an empirical cross-covariance between large numbers of parameters and observations from a limited number of realizations is likely to result in spurious cross-correlations.
#
# Because of this, some parameters will be adjusted when they should not be adjusted.
#
# Furthermore, when large numbers of independent observations comprise a calibration dataset, a small ensemble size will almost certainly not provide enough degrees of freedom to reproduce these data...

# %% [markdown]
# ## `Solutions:`
# - pass ies a csv that explicitly tells it what data can inform which parameters (e.g., so heads don't inform porosity)
# - orrrr `' just run a larger ensemble... (if you can)`
# __________
# Larger ensemble also has the effect of exploring uncertainty (remember we are sampling a distribution!)
#
# ... and for more "accurately" approximating the jacobian
