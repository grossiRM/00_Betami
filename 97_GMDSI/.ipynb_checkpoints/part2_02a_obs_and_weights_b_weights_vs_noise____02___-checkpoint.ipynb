# %% [markdown]
# **Iterative Ensemble Smoother (iES)** `_______Weights_______`

# %%
import flopy ; import matplotlib.pyplot as plt        ; from wvn_helper import plot_mod_obs

# %%
fig = plt.figure(figsize=(13, 4))           ; fig.tight_layout()                  
ax = fig.add_subplot(151, aspect="equal")                 ; plot_mod_obs( 6)
ax = fig.add_subplot(152, aspect="equal")                 ; plot_mod_obs(11, pdc=True)
ax = fig.add_subplot(153, aspect="equal")                 ; plot_mod_obs( 6, noisy=True, std=.5)
ax = fig.add_subplot(154, aspect="equal")                 ; plot_mod_obs(11, noisy=True, std=.5, pdc=True)
ax = fig.add_subplot(155, aspect="equal")                 ; plot_mod_obs(11, noisy=True, std=[.5,5] )
plt.show()

# %%
fig = plt.figure(figsize=(6, 2)); plot_mod_obs( 6); plt.show()
